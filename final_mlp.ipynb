# %%
import pandas as pd
import numpy as np
import torch

from matplotlib import pyplot as plt 

import time

# %%
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
from torchvision import datasets, models, transforms, utils
from sklearn.metrics import confusion_matrix
from torch.utils.data import Dataset, DataLoader
import torchaudio
import torchaudio.transforms as T
import torchvision

import os
import copy

from skimage import io, transform

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()
# Out:
# /home/ghostoftime111/anaconda3/envs/DL/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/ghostoftime111/anaconda3/envs/DL/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#   warn(f"Failed to load image Python extension: {e}")

# %%
from pydub import AudioSegment
from pydub.playback import play
import librosa

# %%
print(torchvision.__version__)
# Out:
# 0.13.1a0

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## preparing dataloader

# %%
data_dir = "/mnt/g/onlinelessons/Multimedia/HW/project/dataset/final_data/"

class audio_custom_dataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, transform=None):
        """
        Arguments:
            csv_file (string): Path to the csv file with labels.
            root_dir (string): Directory with all the audios.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        
        self.audio_csv = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.audio_csv)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        audio_name = self.audio_csv.iloc[idx, 1]
        waveform, sample_rate = torchaudio.load(audio_name)
        transform = T.MFCC(
            sample_rate=sample_rate,
            n_mfcc=31,
            melkwargs={"n_fft": 2048  , "hop_length": 512 , "n_mels": 128, "center": False}
        )
        waveform = transform(waveform)
        
        waveform = nn.functional.normalize(waveform, dim=-1)
        
        
        label = self.audio_csv.iloc[idx, 3:7]
        label = np.array(label, dtype=np.float16)
        
       # sample = {'audio': waveform, 'label': label}
        sample = [torch.flatten(waveform), label]

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
audio_dataset = audio_custom_dataset(csv_file='./dataset/final_data/train_data_encoded.csv')

# %%
audio_dataset

# %%
str(torchaudio.get_audio_backend())
# Out:
# 'sox_io'

# %% [markdown]
# ## loading datas in batches

# %%
def collate_fn(batch):
    return [
      torch.stack([x[0] for x in batch]),
      torch.tensor([x[1] for x in batch])
      #torch.stack([x[audio] for x in batch]),
      #torch.tensor([x[labels] for x in batch])
        ]

# %%
audio_datasets = {x.split("_")[0]: audio_custom_dataset(os.path.join(data_dir, x))
                      for x in ["train_data_encoded.csv", "test_data_encoded.csv", "val_data_encoded.csv"]}
dataloaders = {x: torch.utils.data.DataLoader(audio_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=8, collate_fn=collate_fn)
                      for x in ["train", "test", "val"]}
dataset_sizes = {x: len(audio_datasets[x]) for x in ["train", "test", "val"]}
#class_names = audio_datasets['train'].classes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## data visualization

# %%
train_set = audio_datasets['train']
train_set[6]
# Out:
# [tensor([-0.2386, -0.1726, -0.1243,  ..., -0.1263, -0.1273, -0.0714]),
#  array([1., 0., 0., 0.], dtype=float16)]

# %%
ss = train_set[1][0].shape
ss
# Out:
# torch.Size([2790])

# %%
count = 0
for j, i in enumerate(range(len(train_set))):
    if train_set[i][0].shape == ss:
        continue
    else:
        count +=1
        print(f"index {j} shape is: {train_set[i][0].shape}")
        
        
print(f"count is : {count}")
# Out:
# count is : 0

# %%
dataloaders["train"]

# %%
input_s, classes = next(iter(dataloaders['train']))

# %%
input_s[0]
# Out:
# tensor([-0.1473, -0.1287, -0.1213,  ..., -0.1136, -0.0614, -0.0820])

# %%
classes[0]
# Out:
# tensor([1., 0., 0., 0.], dtype=torch.float16)

# %%
flat = input_s[2].shape[0]
print(f"input shape is :{input_s[2].shape}\nlebel shape is: {classes[0].shape}")
# Out:
# input shape is :torch.Size([2790])
# lebel shape is: torch.Size([4])

# %%
def plot_spectrogram(specgram, title=None, ylabel="freq_bin"):
    fig, axs = plt.subplots(1, 1)
    axs.set_title(title or "Spectrogram (db)")
    axs.set_ylabel(ylabel)
    axs.set_xlabel("frame")
    im = axs.imshow(librosa.power_to_db(specgram), origin="lower", aspect="auto")
    fig.colorbar(im, ax=axs)
    plt.show(block=False)
    
plot_spectrogram(input_s[0].reshape(31, 90), f"{classes[0]}")

# %% [markdown]
# ## training function

# %%
accuracies_train = []
accuracies_val = []

def train_model(model, criterion, optimizer, scheduler, num_epochs=5):
    since = time.time()
    l1_lambda = 0.001
    counter = 0
    patience = 15
    flag = 0

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        if flag:
            break
        
        print('-' * 50)
        print('\033[31m' + f'Epoch {epoch + 1}/{num_epochs}' + '\033[0m')
        

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            print('\033[32m' + f'phase: {phase}' + '\033[0m')
            
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            
            for inputs, labels in dataloaders[phase]:
                
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                
                model.to(device)

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    preds = outputs
                    loss = criterion(preds, labels)
                    
                            # Compute L1 regularization loss
                    l1_loss = 0
                    for param in model.parameters():
                        l1_loss += torch.norm(param, 2)

                    # Add L2 regularization to the total loss
                    loss += l1_lambda * l1_loss


                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                # print(preds)
                running_loss += loss.item() * inputs.size(0)
                chosen_label = torch.argmax(labels, dim=1)
                predicted_value = torch.argmax(preds, dim=1)
                # print("batch labels:")
                # print('\033[34m' + f"{chosen_label}" + '\033[0m')
                # print("pred labels:")
                # print('\033[34m' + f"{predicted_value}" + '\033[0m')
                # print("-" * 10)
                
                running_corrects += torch.sum(chosen_label == predicted_value)
                
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            
            if phase == 'val':
                accuracies_val.append(epoch_acc)
                
            else:
                accuracies_train.append(epoch_acc)

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                counter = 0
                print(counter)
            elif phase == 'val':
                counter = counter + 1
                print(counter)
                
            if counter >= patience:
                print("Early stopping after {} epochs".format(epoch))
                flag = 1
                break

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## preparing model

# %%
class MLP_Audio_Model(torch.nn.Module):

    def __init__(self):
        super(MLP_Audio_Model3, self).__init__()


        self.linear1 = torch.nn.Linear(2790, 512)
        self.bachNoem1 = nn.BatchNorm1d(512)
        self.activation1 = torch.nn.ReLU()
        self.dropout1 = nn.Dropout(p=0.5)

        # self.linear2 = torch.nn.Linear(1024, 512)
        # self.bachNoem2 = nn.BatchNorm1d(512)
        # self.activation2 = torch.nn.ReLU()
        # self.dropout2 = nn.Dropout(p=0.5)

        self.linear3 = torch.nn.Linear(512, 128)
        self.bachNoem3 = torch.nn.BatchNorm1d(128)
        self.dropout3 = nn.Dropout(p=0.5)
        self.activation3 = torch.nn.ReLU()

#         self.linear4 = torch.nn.Linear(256, 128)
#         self.bachNoem4 = torch.nn.BatchNorm1d(128)
#         self.dropout4 = nn.Dropout(p=0.3)
#         self.activation4 = torch.nn.ReLU()
        
        self.linear6 = torch.nn.Linear(128, 64)
        self.bachNoem6 = torch.nn.BatchNorm1d(64)
        self.dropout6 = nn.Dropout(p=0.5)
        self.activation6 = torch.nn.ReLU()
        
        # self.linear7 = torch.nn.Linear(64, 32)
        # self.bachNoem7 = torch.nn.BatchNorm1d(32)
        # self.dropout7 = nn.Dropout(p=0.5)
        # self.activation7 = torch.nn.ReLU()
        
        self.linear8 = torch.nn.Linear(64, 16)
        self.bachNoem8 = torch.nn.BatchNorm1d(16)
        self.dropout8 = nn.Dropout(p=0.5)
        self.activation8 = torch.nn.ReLU()
        
#         self.linear9 = torch.nn.Linear(32, 16)
#         self.bachNoem9 = torch.nn.BatchNorm1d(16)
#         self.dropout9 = nn.Dropout(p=0.2)
#         self.activation9 = torch.nn.ReLU()

        self.linear5 = torch.nn.Linear(16, 4)

        self.softmax = torch.nn.Softmax(dim = 1)

    def forward(self, x):
        x = self.linear1(x)
        x = self.bachNoem1(x)
        x = self.activation1(x)
        x = self.dropout1(x)

        # x = self.linear2(x)
        # x = self.bachNoem2(x)
        # x = self.activation2(x)
        # x = self.dropout2(x)

        x = self.linear3(x)
        x = self.bachNoem3(x)
        x = self.activation3(x)
        x = self.dropout3(x)

        # x = self.linear4(x)
        # x = self.bachNoem4(x)
        # x = self.activation4(x)
        # x = self.dropout4(x)

        x = self.linear6(x)
        x = self.bachNoem6(x)
        x = self.activation6(x)
        x = self.dropout6(x)
        
        # x = self.linear7(x)
        # x = self.bachNoem7(x)
        # x = self.activation7(x)
        # x = self.dropout7(x)
        
        x = self.linear8(x)
        x = self.bachNoem8(x)
        x = self.activation8(x)
        x = self.dropout8(x)   
        
        
        x = self.linear5(x)

        x = self.softmax(x)
        return x

MLP_model = MLP_Audio_Model3()

print('The model:')
print(MLP_model)

# print('\n\nModel params:')
# for param in MLP_model.parameters():
#     print(param)
# Out:
# The model:
# MLP_Audio_Model3(
#   (linear1): Linear(in_features=2790, out_features=512, bias=True)
#   (bachNoem1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation1): ReLU()
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (linear3): Linear(in_features=512, out_features=128, bias=True)
#   (bachNoem3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (activation3): ReLU()
#   (linear6): Linear(in_features=128, out_features=64, bias=True)
#   (bachNoem6): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout6): Dropout(p=0.5, inplace=False)
#   (activation6): ReLU()
#   (linear8): Linear(in_features=64, out_features=16, bias=True)
#   (bachNoem8): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout8): Dropout(p=0.5, inplace=False)
#   (activation8): ReLU()
#   (linear5): Linear(in_features=16, out_features=4, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ## training proccess

# %%
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(MLP_model.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.1)

num_epochs = 300

MLP_model = train_model(MLP_model, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=num_epochs)
# Out:
# --------------------------------------------------
# Epoch 1/300
# phase: train
# train Loss: 1.4701 Acc: 0.2329
# phase: val
# val Loss: 1.4547 Acc: 0.2840
# 0
#
# --------------------------------------------------
# Epoch 2/300
# phase: train
# train Loss: 1.4670 Acc: 0.2566
# phase: val
# val Loss: 1.4489 Acc: 0.3086
# 0
#
# --------------------------------------------------
# Epoch 3/300
# phase: train
# train Loss: 1.4499 Acc: 0.3120
# phase: val
# val Loss: 1.4243 Acc: 0.4568
# 0
#
# --------------------------------------------------
# Epoch 4/300
# phase: train
# train Loss: 1.4366 Acc: 0.3638
# phase: val
# val Loss: 1.3801 Acc: 0.5802
# 0
#
# --------------------------------------------------
# Epoch 5/300
# phase: train
# train Loss: 1.3978 Acc: 0.4262
# phase: val
# val Loss: 1.3507 Acc: 0.5926
# 0
#
# --------------------------------------------------
# Epoch 6/300
# phase: train
# train Loss: 1.3532 Acc: 0.4947
# phase: val
# val Loss: 1.2860 Acc: 0.6481
# 0
#
# --------------------------------------------------
# Epoch 7/300
# phase: train
# train Loss: 1.3102 Acc: 0.5650
# phase: val
# val Loss: 1.2473 Acc: 0.7160
# 0
#
# --------------------------------------------------
# Epoch 8/300
# phase: train
# train Loss: 1.2698 Acc: 0.6160
# phase: val
# val Loss: 1.1711 Acc: 0.7654
# 0
#
# --------------------------------------------------
# Epoch 9/300
# phase: train
# train Loss: 1.2447 Acc: 0.6230
# phase: val
# val Loss: 1.1135 Acc: 0.8025
# 0
#
# --------------------------------------------------
# Epoch 10/300
# phase: train
# train Loss: 1.2094 Acc: 0.6652
# phase: val
# val Loss: 1.1362 Acc: 0.7593
# 1
#
# --------------------------------------------------
# Epoch 11/300
# phase: train
# train Loss: 1.1956 Acc: 0.6784
# phase: val
# val Loss: 1.1198 Acc: 0.7840
# 2
#
# --------------------------------------------------
# Epoch 12/300
# phase: train
# train Loss: 1.1689 Acc: 0.7100
# phase: val
# val Loss: 1.1089 Acc: 0.8025
# 3
#
# --------------------------------------------------
# Epoch 13/300
# phase: train
# train Loss: 1.1668 Acc: 0.7100
# phase: val
# val Loss: 1.1006 Acc: 0.8025
# 4
#
# --------------------------------------------------
# Epoch 14/300
# phase: train
# train Loss: 1.1683 Acc: 0.7144
# phase: val
# val Loss: 1.0657 Acc: 0.8395
# 0
#
# --------------------------------------------------
# Epoch 15/300
# phase: train
# train Loss: 1.1521 Acc: 0.7390
# phase: val
# val Loss: 1.0632 Acc: 0.8333
# 1
#
# --------------------------------------------------
# Epoch 16/300
# phase: train
# train Loss: 1.1576 Acc: 0.7162
# phase: val
# val Loss: 1.0745 Acc: 0.8395
# 2
#
# --------------------------------------------------
# Epoch 17/300
# phase: train
# train Loss: 1.1377 Acc: 0.7583
# phase: val
# val Loss: 1.0720 Acc: 0.8333
# 3
#
# --------------------------------------------------
# Epoch 18/300
# phase: train
# train Loss: 1.1269 Acc: 0.7654
# phase: val
# val Loss: 1.0839 Acc: 0.7963
# 4
#
# --------------------------------------------------
# Epoch 19/300
# phase: train
# train Loss: 1.1336 Acc: 0.7540
# phase: val
# val Loss: 1.0437 Acc: 0.8272
# 5
#
# --------------------------------------------------
# Epoch 20/300
# phase: train
# train Loss: 1.1249 Acc: 0.7513
# phase: val
# val Loss: 1.0484 Acc: 0.8519
# 0
#
# --------------------------------------------------
# Epoch 21/300
# phase: train
# train Loss: 1.1411 Acc: 0.7434
# phase: val
# val Loss: 1.0421 Acc: 0.8642
# 0
#
# --------------------------------------------------
# Epoch 22/300
# phase: train
# train Loss: 1.1249 Acc: 0.7645
# phase: val
# val Loss: 1.0430 Acc: 0.8704
# 0
#
# --------------------------------------------------
# Epoch 23/300
# phase: train
# train Loss: 1.1174 Acc: 0.7750
# phase: val
# val Loss: 1.0338 Acc: 0.8642
# 1
#
# --------------------------------------------------
# Epoch 24/300
# phase: train
# train Loss: 1.1256 Acc: 0.7671
# phase: val
# val Loss: 1.0423 Acc: 0.8519
# 2
#
# --------------------------------------------------
# Epoch 25/300
# phase: train
# train Loss: 1.1221 Acc: 0.7654
# phase: val
# val Loss: 1.0276 Acc: 0.8827
# 0
#
# --------------------------------------------------
# Epoch 26/300
# phase: train
# train Loss: 1.1446 Acc: 0.7346
# phase: val
# val Loss: 1.0291 Acc: 0.8519
# 1
#
# --------------------------------------------------
# Epoch 27/300
# phase: train
# train Loss: 1.1404 Acc: 0.7540
# phase: val
# val Loss: 1.0362 Acc: 0.8519
# 2
#
# --------------------------------------------------
# Epoch 28/300
# phase: train
# train Loss: 1.1272 Acc: 0.7575
# phase: val
# val Loss: 1.0581 Acc: 0.8333
# 3
#
# --------------------------------------------------
# Epoch 29/300
# phase: train
# train Loss: 1.1279 Acc: 0.7654
# phase: val
# val Loss: 1.0234 Acc: 0.8827
# 4
#
# --------------------------------------------------
# Epoch 30/300
# phase: train
# train Loss: 1.1371 Acc: 0.7469
# phase: val
# val Loss: 1.0283 Acc: 0.8889
# 0
#
# --------------------------------------------------
# Epoch 31/300
# phase: train
# train Loss: 1.1370 Acc: 0.7583
# phase: val
# val Loss: 1.0278 Acc: 0.8580
# 1
#
# --------------------------------------------------
# Epoch 32/300
# phase: train
# train Loss: 1.1148 Acc: 0.7750
# phase: val
# val Loss: 1.0373 Acc: 0.8580
# 2
#
# --------------------------------------------------
# Epoch 33/300
# phase: train
# train Loss: 1.1254 Acc: 0.7583
# phase: val
# val Loss: 1.0281 Acc: 0.8827
# 3
#
# --------------------------------------------------
# Epoch 34/300
# phase: train
# train Loss: 1.1313 Acc: 0.7469
# phase: val
# val Loss: 1.0235 Acc: 0.8889
# 4
#
# --------------------------------------------------
# Epoch 35/300
# phase: train
# train Loss: 1.1336 Acc: 0.7469
# phase: val
# val Loss: 1.0236 Acc: 0.8642
# 5
#
# --------------------------------------------------
# Epoch 36/300
# phase: train
# train Loss: 1.1094 Acc: 0.7768
# phase: val
# val Loss: 1.0225 Acc: 0.8889
# 6
#
# --------------------------------------------------
# Epoch 37/300
# phase: train
# train Loss: 1.1302 Acc: 0.7531
# phase: val
# val Loss: 1.0398 Acc: 0.8519
# 7
#
# --------------------------------------------------
# Epoch 38/300
# phase: train
# train Loss: 1.1135 Acc: 0.7759
# phase: val
# val Loss: 1.0324 Acc: 0.8457
# 8
#
# --------------------------------------------------
# Epoch 39/300
# phase: train
# train Loss: 1.1243 Acc: 0.7733
# phase: val
# val Loss: 1.0380 Acc: 0.8580
# 9
#
# --------------------------------------------------
# Epoch 40/300
# phase: train
# train Loss: 1.1302 Acc: 0.7531
# phase: val
# val Loss: 1.0256 Acc: 0.8827
# 10
#
# --------------------------------------------------
# Epoch 41/300
# phase: train
# train Loss: 1.1286 Acc: 0.7408
# phase: val
# val Loss: 1.0372 Acc: 0.8827
# 11
#
# --------------------------------------------------
# Epoch 42/300
# phase: train
# train Loss: 1.1151 Acc: 0.7786
# phase: val
# val Loss: 1.0239 Acc: 0.8827
# 12
#
# --------------------------------------------------
# Epoch 43/300
# phase: train
# train Loss: 1.1317 Acc: 0.7504
# phase: val
# val Loss: 1.0303 Acc: 0.8519
# 13
#
# --------------------------------------------------
# Epoch 44/300
# phase: train
# train Loss: 1.1340 Acc: 0.7557
# phase: val
# val Loss: 1.0269 Acc: 0.8827
# 14
#
# --------------------------------------------------
# Epoch 45/300
# phase: train
# train Loss: 1.1125 Acc: 0.7698
# phase: val
# val Loss: 1.0502 Acc: 0.8457
# 15
# Early stopping after 44 epochs
#
# Training complete in 6m 39s
# Best val Acc: 0.888889

# %% [markdown]
# ## accuracy visualization

# %%
def ToCPU(in_tensor):
    return in_tensor.to("cpu")

def learnin_graph(acc_train, acc_val, epochs): 
    x = list(range(epochs))
    fig, ax = plt.subplots(figsize=(10, 5))
    # print(f"acc_train :{acc_train}")
    # print(f"acc_val :{acc_val}")
    ax.plot(x, acc_train, label='accuracies_train')
    ax.plot(x, acc_val, label='accuracies_val')
    ax.legend()
    plt.show()

learnin_graph(list(map(ToCPU, accuracies_train)), list(map(ToCPU, accuracies_val)),62)

# %% [markdown]
# ## saving best model

# %%
best_val = max(accuracies_val)
path_to_model = "MLP_" + f"{best_val:6f}" + "new_model3.pt"
torch.save(MLP_model, path_to_model)

# %%
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## visualizing test results

# %%
def visualize_model(model):
    true_labels = []
    predicted_labels = []
        
    was_training = model.training
    model.eval()
    correct = 0
    total = 0
    running_corrects = 0
    
    fig = plt.figure()
    model = model.to(device)

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            preds = outputs

            chosen_label = torch.argmax(labels, dim=1)
            print('\033[30m' + f'label:     {chosen_label}' + '\033[0m')
            
            predicted_value = torch.argmax(preds, dim=1)
            print('\033[31m' + f'predicted: {predicted_value}' + '\033[0m')
            
            print('\033[33m' + f'predicted: {preds}' + '\033[0m')
            
            running_corrects = torch.sum(chosen_label == predicted_value)         
            correct = correct + running_corrects
            print('\033[32m' + f'corrects:: {correct}' + '\033[0m')
            
            total = total + inputs.size(0)
            print('\033[34m' + f'total: {total}' + '\033[0m')
            
            true_labels.extend(chosen_label.to("cpu").numpy())
            predicted_labels.extend(predicted_value.to("cpu").numpy())
            
            
        accuracy = 100 * correct / total
        print('\033[35m' + f'acuuracy: {accuracy}' + '\033[0m')   
            
        model.train(mode=was_training)
        
        
    conf_matrix = confusion_matrix(true_labels, predicted_labels)

    # Plot the confusion matrix
    plt.imshow(conf_matrix, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.colorbar()
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()

# %%
for model_dir in os.listdir("./"):
    if model_dir.split(".")[-1] != "pt":
        continue
    print(model_dir)
# Out:
# best.pt
# CNN_0.962963.pt
# MLP_0.761364.pt
# MLP_0.851064.pt
# MLP_0.872340.pt
# MLP_0.888889new_model3.pt
# MLP_0.893617.pt
# MLP_0.914894.pt
# MLP_0.919753.pt
# MLP_0.919753new_model2.pt
# MLP_0.932099new_model3.pt
# MLP_0.936170.pt
# MLP_0.936170_best.pt
# MLP_0.936170_old.pt
# MLP_0.938272new_model3.pt

# %% [markdown]
# ## loading desired model

# %%
current_dir = os.getcwd()
model_path = current_dir + '/' + "MLP_0.888889new_model3.pt"

test_model = MLP_Audio_Model3()
test_model = torch.load(model_path)

# %% [markdown]
# ## test results and confusion matrix

# %%
visualize_model(test_model)
# Out:
# label:     tensor([2, 2, 3, 1, 3, 2, 0, 0], device='cuda:0')
# predicted: tensor([2, 2, 3, 3, 0, 2, 0, 0], device='cuda:0')
# predicted: tensor([[0.0014, 0.0050, 0.9922, 0.0014],
#         [0.0078, 0.0188, 0.9677, 0.0058],
#         [0.0517, 0.0121, 0.0337, 0.9025],
#         [0.2243, 0.1543, 0.1150, 0.5064],
#         [0.4971, 0.0635, 0.1145, 0.3249],
#         [0.0348, 0.1224, 0.8232, 0.0196],
#         [0.9740, 0.0049, 0.0091, 0.0120],
#         [0.7720, 0.0512, 0.1003, 0.0765]], device='cuda:0')
# corrects:: 6
# total: 8
# label:     tensor([2, 3, 3, 0, 1, 0, 0, 2], device='cuda:0')
# predicted: tensor([2, 3, 3, 0, 1, 0, 0, 2], device='cuda:0')
# predicted: tensor([[2.2302e-02, 1.4498e-01, 8.1981e-01, 1.2903e-02],
#         [1.1154e-01, 7.9129e-02, 5.4613e-02, 7.5472e-01],
#         [1.1969e-02, 1.7278e-03, 5.4074e-03, 9.8090e-01],
#         [9.3660e-01, 1.3064e-02, 1.8175e-02, 3.2157e-02],
#         [4.5373e-04, 9.9293e-01, 6.3919e-03, 2.2013e-04],
#         [8.6471e-01, 3.8454e-02, 4.7756e-02, 4.9080e-02],
#         [8.8402e-01, 2.6398e-02, 3.9838e-02, 4.9745e-02],
#         [1.6621e-02, 1.2421e-01, 8.4975e-01, 9.4168e-03]], device='cuda:0')
# corrects:: 14
# total: 16
# label:     tensor([1, 1, 3, 0, 1, 3, 2, 2], device='cuda:0')
# predicted: tensor([1, 1, 3, 0, 1, 3, 2, 2], device='cuda:0')
# predicted: tensor([[2.7296e-03, 9.6923e-01, 2.6760e-02, 1.2773e-03],
#         [2.3295e-03, 9.6881e-01, 2.7752e-02, 1.1112e-03],
#         [1.9300e-02, 4.2169e-03, 9.1187e-03, 9.6736e-01],
#         [9.1286e-01, 1.9030e-02, 2.4963e-02, 4.3150e-02],
#         [1.3330e-02, 9.3489e-01, 4.5268e-02, 6.5070e-03],
#         [2.8927e-01, 2.8458e-02, 4.5730e-02, 6.3655e-01],
#         [1.6743e-02, 2.6762e-02, 9.4428e-01, 1.2212e-02],
#         [3.5634e-04, 1.8483e-03, 9.9744e-01, 3.5762e-04]], device='cuda:0')
# corrects:: 22
# total: 24
# label:     tensor([3, 2, 1, 2, 2, 3, 1, 0], device='cuda:0')
# predicted: tensor([3, 2, 1, 2, 2, 3, 1, 1], device='cuda:0')
# predicted: tensor([[8.4599e-02, 1.7316e-02, 3.4811e-02, 8.6327e-01],
#         [2.1816e-02, 4.5587e-02, 9.1775e-01, 1.4849e-02],
#         [7.5995e-03, 9.4291e-01, 4.5905e-02, 3.5880e-03],
#         [7.4743e-03, 1.2617e-02, 9.7271e-01, 7.2032e-03],
#         [1.5047e-02, 7.5875e-02, 8.9942e-01, 9.6577e-03],
#         [1.5087e-02, 2.2041e-03, 6.0813e-03, 9.7663e-01],
#         [7.0784e-04, 9.9118e-01, 7.7201e-03, 3.8714e-04],
#         [1.9738e-02, 8.6155e-01, 1.0839e-01, 1.0318e-02]], device='cuda:0')
# corrects:: 29
# total: 32
# label:     tensor([0, 3, 1, 2, 1, 2, 1, 3], device='cuda:0')
# predicted: tensor([0, 0, 1, 2, 1, 2, 1, 3], device='cuda:0')
# predicted: tensor([[9.6102e-01, 8.1795e-03, 1.1232e-02, 1.9572e-02],
#         [4.4430e-01, 4.3055e-02, 7.0639e-02, 4.4201e-01],
#         [3.0058e-04, 9.9360e-01, 5.9661e-03, 1.3402e-04],
#         [7.7580e-03, 2.5480e-02, 9.6049e-01, 6.2759e-03],
#         [8.7311e-04, 9.8784e-01, 1.0853e-02, 4.3537e-04],
#         [2.7936e-02, 4.1374e-02, 9.0503e-01, 2.5661e-02],
#         [3.5188e-01, 4.3934e-01, 1.3905e-01, 6.9739e-02],
#         [5.0007e-02, 1.1324e-02, 2.7472e-02, 9.1120e-01]], device='cuda:0')
# corrects:: 36
# total: 40
# label:     tensor([2, 1, 0, 0, 1, 2, 1, 2], device='cuda:0')
# predicted: tensor([2, 1, 0, 1, 1, 2, 1, 1], device='cuda:0')
# predicted: tensor([[3.4022e-01, 1.1114e-01, 4.0534e-01, 1.4330e-01],
#         [5.2857e-05, 9.9861e-01, 1.3137e-03, 2.6418e-05],
#         [6.1616e-01, 5.2555e-02, 7.4724e-02, 2.5656e-01],
#         [1.6117e-01, 6.7149e-01, 1.2862e-01, 3.8729e-02],
#         [1.0651e-03, 9.8723e-01, 1.1134e-02, 5.6855e-04],
#         [9.1572e-02, 9.7871e-02, 6.9512e-01, 1.1544e-01],
#         [1.9780e-04, 9.9098e-01, 8.7492e-03, 7.1458e-05],
#         [2.8303e-01, 3.8920e-01, 2.4168e-01, 8.6092e-02]], device='cuda:0')
# corrects:: 42
# total: 48
# label:     tensor([1, 2, 3, 0, 0, 2, 1, 1], device='cuda:0')
# predicted: tensor([1, 2, 3, 0, 0, 2, 1, 1], device='cuda:0')
# predicted: tensor([[2.6099e-02, 5.1742e-01, 4.4439e-01, 1.2094e-02],
#         [2.6785e-02, 3.7356e-02, 9.1933e-01, 1.6531e-02],
#         [4.3351e-02, 9.4588e-03, 2.7569e-02, 9.1962e-01],
#         [5.1539e-01, 2.5899e-01, 1.3449e-01, 9.1135e-02],
#         [7.4936e-01, 4.9702e-02, 8.4965e-02, 1.1597e-01],
#         [7.1131e-03, 2.2851e-02, 9.6472e-01, 5.3195e-03],
#         [4.1160e-04, 9.9415e-01, 5.2168e-03, 2.1906e-04],
#         [1.9842e-04, 9.9096e-01, 8.7655e-03, 7.1691e-05]], device='cuda:0')
# corrects:: 50
# total: 56
# label:     tensor([2, 1, 1, 1, 2, 3, 3, 3], device='cuda:0')
# predicted: tensor([2, 1, 1, 1, 2, 0, 3, 3], device='cuda:0')
# predicted: tensor([[7.2782e-02, 7.8693e-02, 8.0701e-01, 4.1511e-02],
#         [8.1981e-02, 8.3351e-01, 6.5953e-02, 1.8551e-02],
#         [1.7373e-01, 4.0232e-01, 2.5784e-01, 1.6611e-01],
#         [1.0113e-03, 9.8815e-01, 1.0280e-02, 5.5352e-04],
#         [1.4805e-02, 3.1479e-02, 9.4146e-01, 1.2252e-02],
#         [4.3521e-01, 2.1488e-01, 2.1764e-01, 1.3227e-01],
#         [1.5155e-02, 2.6493e-03, 1.0496e-02, 9.7170e-01],
#         [2.2553e-02, 4.3228e-03, 1.3101e-02, 9.6002e-01]], device='cuda:0')
# corrects:: 57
# total: 64
# label:     tensor([2, 1, 0, 0, 0, 3, 2, 2], device='cuda:0')
# predicted: tensor([2, 1, 1, 1, 0, 2, 2, 2], device='cuda:0')
# predicted: tensor([[3.4559e-01, 1.1462e-01, 4.4365e-01, 9.6138e-02],
#         [7.7676e-05, 9.9819e-01, 1.6954e-03, 3.9056e-05],
#         [3.0710e-02, 7.6595e-01, 1.8753e-01, 1.5803e-02],
#         [1.4130e-01, 5.3300e-01, 2.6599e-01, 5.9708e-02],
#         [9.4292e-01, 1.2005e-02, 1.9102e-02, 2.5970e-02],
#         [1.3387e-01, 3.2883e-01, 4.4186e-01, 9.5442e-02],
#         [1.5955e-03, 4.5622e-03, 9.9218e-01, 1.6615e-03],
#         [2.6735e-02, 1.2416e-01, 8.3327e-01, 1.5835e-02]], device='cuda:0')
# corrects:: 62
# total: 72
# label:     tensor([1, 2, 1, 0, 0, 3, 3, 3], device='cuda:0')
# predicted: tensor([1, 1, 1, 0, 0, 3, 2, 3], device='cuda:0')
# predicted: tensor([[5.5698e-04, 9.9217e-01, 6.9765e-03, 2.9586e-04],
#         [9.2933e-04, 9.8890e-01, 9.6732e-03, 5.0078e-04],
#         [1.7312e-01, 4.0337e-01, 2.5883e-01, 1.6468e-01],
#         [9.7049e-01, 5.7709e-03, 1.0198e-02, 1.3541e-02],
#         [9.5108e-01, 1.2247e-02, 1.4344e-02, 2.2331e-02],
#         [1.7247e-02, 3.0274e-03, 7.3872e-03, 9.7234e-01],
#         [1.4566e-01, 9.2439e-02, 6.4592e-01, 1.1598e-01],
#         [2.6544e-02, 3.9520e-03, 1.0036e-02, 9.5947e-01]], device='cuda:0')
# corrects:: 68
# total: 80
# label:     tensor([3, 0, 1, 3, 0, 0, 0, 1], device='cuda:0')
# predicted: tensor([3, 0, 2, 3, 0, 0, 2, 1], device='cuda:0')
# predicted: tensor([[0.0779, 0.0255, 0.0936, 0.8029],
#         [0.9692, 0.0059, 0.0091, 0.0158],
#         [0.0052, 0.0137, 0.9769, 0.0042],
#         [0.0310, 0.0075, 0.0299, 0.9316],
#         [0.9194, 0.0185, 0.0238, 0.0384],
#         [0.9079, 0.0194, 0.0373, 0.0354],
#         [0.2831, 0.1351, 0.5008, 0.0810],
#         [0.0151, 0.9152, 0.0622, 0.0075]], device='cuda:0')
# corrects:: 74
# total: 88
# label:     tensor([3, 0, 1, 0, 3, 0, 2, 2], device='cuda:0')
# predicted: tensor([3, 0, 3, 0, 3, 1, 2, 2], device='cuda:0')
# predicted: tensor([[0.3207, 0.0701, 0.1110, 0.4982],
#         [0.8970, 0.0259, 0.0382, 0.0389],
#         [0.3172, 0.1532, 0.1738, 0.3558],
#         [0.7958, 0.0706, 0.0643, 0.0693],
#         [0.0520, 0.0113, 0.0284, 0.9082],
#         [0.0198, 0.8600, 0.1099, 0.0104],
#         [0.0011, 0.0050, 0.9928, 0.0011],
#         [0.0358, 0.0516, 0.8923, 0.0203]], device='cuda:0')
# corrects:: 80
# total: 96
# label:     tensor([0, 1, 1, 1, 3, 1, 1, 0], device='cuda:0')
# predicted: tensor([0, 1, 3, 1, 3, 1, 1, 0], device='cuda:0')
# predicted: tensor([[8.8919e-01, 3.5445e-02, 3.1646e-02, 4.3717e-02],
#         [2.5415e-03, 9.6994e-01, 2.6274e-02, 1.2476e-03],
#         [2.2370e-01, 1.5205e-01, 1.1434e-01, 5.0991e-01],
#         [2.0412e-04, 9.9452e-01, 5.1973e-03, 8.0148e-05],
#         [8.1445e-02, 2.5095e-02, 5.5010e-02, 8.3845e-01],
#         [8.7818e-02, 7.5704e-01, 1.2931e-01, 2.5832e-02],
#         [1.2980e-04, 9.9536e-01, 4.4662e-03, 4.8617e-05],
#         [8.2081e-01, 4.0551e-02, 6.9464e-02, 6.9173e-02]], device='cuda:0')
# corrects:: 87
# total: 104
# label:     tensor([0, 1, 2, 3, 0, 3, 2, 0], device='cuda:0')
# predicted: tensor([1, 1, 2, 3, 1, 2, 2, 0], device='cuda:0')
# predicted: tensor([[1.6216e-01, 6.7003e-01, 1.2891e-01, 3.8893e-02],
#         [1.9409e-03, 9.6191e-01, 3.5250e-02, 8.9575e-04],
#         [8.0973e-03, 1.7232e-02, 9.6717e-01, 7.5011e-03],
#         [3.2593e-02, 9.2538e-03, 4.2082e-02, 9.1607e-01],
#         [8.4705e-02, 6.3496e-01, 2.4554e-01, 3.4797e-02],
#         [5.4252e-02, 5.7039e-02, 8.2726e-01, 6.1453e-02],
#         [2.7334e-01, 9.5069e-02, 5.7034e-01, 6.1249e-02],
#         [8.8597e-01, 2.5646e-02, 3.9619e-02, 4.8765e-02]], device='cuda:0')
# corrects:: 92
# total: 112
# label:     tensor([3, 3, 1, 1, 2, 1, 2, 0], device='cuda:0')
# predicted: tensor([2, 3, 1, 1, 2, 1, 2, 0], device='cuda:0')
# predicted: tensor([[2.4977e-01, 1.8316e-01, 4.0617e-01, 1.6091e-01],
#         [3.7936e-02, 8.8258e-03, 1.9245e-02, 9.3399e-01],
#         [1.5301e-02, 9.1493e-01, 6.2215e-02, 7.5576e-03],
#         [2.7273e-04, 9.9445e-01, 5.1503e-03, 1.2876e-04],
#         [1.7229e-02, 3.0037e-02, 9.4016e-01, 1.2573e-02],
#         [8.2359e-04, 9.8610e-01, 1.2716e-02, 3.6423e-04],
#         [6.3701e-03, 1.0184e-02, 9.7790e-01, 5.5489e-03],
#         [8.3705e-01, 4.1350e-02, 5.8012e-02, 6.3583e-02]], device='cuda:0')
# corrects:: 99
# total: 120
# label:     tensor([3, 2, 3, 2, 3, 2, 1, 0], device='cuda:0')
# predicted: tensor([2, 2, 3, 2, 2, 2, 1, 2], device='cuda:0')
# predicted: tensor([[5.2768e-02, 3.5238e-02, 7.2457e-01, 1.8742e-01],
#         [1.9739e-03, 8.3290e-03, 9.8773e-01, 1.9629e-03],
#         [7.4681e-03, 8.4876e-04, 2.5707e-03, 9.8911e-01],
#         [1.9042e-03, 6.6809e-03, 9.8983e-01, 1.5890e-03],
#         [1.8050e-01, 7.4641e-02, 3.7550e-01, 3.6936e-01],
#         [5.0135e-02, 6.9045e-02, 8.4266e-01, 3.8158e-02],
#         [1.2606e-03, 9.8713e-01, 1.0888e-02, 7.1961e-04],
#         [2.6318e-02, 3.7116e-01, 5.8955e-01, 1.2976e-02]], device='cuda:0')
# corrects:: 104
# total: 128
# label:     tensor([3, 3, 0, 0, 3, 3, 0, 1], device='cuda:0')
# predicted: tensor([3, 3, 0, 0, 3, 2, 0, 1], device='cuda:0')
# predicted: tensor([[7.4604e-03, 8.4752e-04, 2.5673e-03, 9.8912e-01],
#         [1.3859e-01, 5.7182e-02, 1.2354e-01, 6.8069e-01],
#         [7.9209e-01, 6.9907e-02, 6.7899e-02, 7.0104e-02],
#         [9.7436e-01, 4.7624e-03, 6.2643e-03, 1.4613e-02],
#         [3.6515e-02, 6.6794e-03, 1.7322e-02, 9.3948e-01],
#         [5.3981e-02, 6.1182e-02, 8.4087e-01, 4.3969e-02],
#         [9.5854e-01, 8.4461e-03, 1.3017e-02, 2.0002e-02],
#         [1.4347e-02, 9.0615e-01, 7.1279e-02, 8.2228e-03]], device='cuda:0')
# corrects:: 111
# total: 136
# label:     tensor([0, 3, 3, 2, 0, 3, 1, 3], device='cuda:0')
# predicted: tensor([0, 1, 3, 2, 0, 3, 1, 3], device='cuda:0')
# predicted: tensor([[0.8646, 0.0319, 0.0471, 0.0564],
#         [0.2579, 0.2931, 0.2528, 0.1961],
#         [0.0482, 0.0111, 0.0186, 0.9221],
#         [0.0182, 0.0418, 0.9264, 0.0135],
#         [0.9560, 0.0086, 0.0157, 0.0198],
#         [0.0979, 0.0252, 0.0521, 0.8248],
#         [0.0051, 0.9606, 0.0316, 0.0027],
#         [0.0724, 0.0202, 0.0520, 0.8554]], device='cuda:0')
# corrects:: 118
# total: 144
# label:     tensor([0, 0, 1, 2, 3, 2, 3, 3], device='cuda:0')
# predicted: tensor([0, 2, 1, 2, 3, 2, 3, 3], device='cuda:0')
# predicted: tensor([[0.6375, 0.0798, 0.1668, 0.1159],
#         [0.0910, 0.1096, 0.7354, 0.0641],
#         [0.0063, 0.9493, 0.0412, 0.0033],
#         [0.0265, 0.0442, 0.9105, 0.0188],
#         [0.0986, 0.3643, 0.0828, 0.4544],
#         [0.0187, 0.0335, 0.9339, 0.0139],
#         [0.1021, 0.0152, 0.0359, 0.8468],
#         [0.0193, 0.0029, 0.0076, 0.9701]], device='cuda:0')
# corrects:: 125
# total: 152
# label:     tensor([0, 0, 1, 3, 1, 1, 2, 1], device='cuda:0')
# predicted: tensor([0, 0, 1, 3, 1, 1, 2, 1], device='cuda:0')
# predicted: tensor([[9.6388e-01, 6.6476e-03, 1.1192e-02, 1.8276e-02],
#         [9.2687e-01, 1.5138e-02, 2.8267e-02, 2.9722e-02],
#         [1.4340e-04, 9.9644e-01, 3.3524e-03, 6.6966e-05],
#         [1.3663e-01, 4.4593e-02, 1.1064e-01, 7.0813e-01],
#         [1.0408e-03, 9.8744e-01, 1.0960e-02, 5.5553e-04],
#         [7.5766e-03, 9.5721e-01, 3.2126e-02, 3.0866e-03],
#         [2.4423e-01, 9.2742e-02, 5.5683e-01, 1.0620e-01],
#         [2.2102e-02, 5.1493e-01, 4.5252e-01, 1.0445e-02]], device='cuda:0')
# corrects:: 133
# total: 160
# label:     tensor([0, 0, 0, 0, 2, 3, 1, 2], device='cuda:0')
# predicted: tensor([0, 0, 0, 0, 2, 3, 1, 1], device='cuda:0')
# predicted: tensor([[6.3090e-01, 1.6859e-01, 1.0193e-01, 9.8574e-02],
#         [8.4714e-01, 3.2835e-02, 5.8261e-02, 6.1768e-02],
#         [6.9019e-01, 9.3860e-02, 1.0636e-01, 1.0959e-01],
#         [8.6407e-01, 3.1989e-02, 4.7353e-02, 5.6586e-02],
#         [2.4313e-02, 3.0826e-02, 9.3108e-01, 1.3782e-02],
#         [6.7036e-02, 1.4690e-02, 3.2004e-02, 8.8627e-01],
#         [1.3064e-03, 9.8510e-01, 1.2906e-02, 6.8920e-04],
#         [2.8376e-01, 3.8918e-01, 2.4086e-01, 8.6192e-02]], device='cuda:0')
# corrects:: 140
# total: 168
# label:     tensor([2, 2, 3, 2, 0, 3, 2, 1], device='cuda:0')
# predicted: tensor([2, 2, 3, 2, 0, 3, 2, 1], device='cuda:0')
# predicted: tensor([[0.0167, 0.0267, 0.9444, 0.0122],
#         [0.0043, 0.0094, 0.9823, 0.0040],
#         [0.0396, 0.0096, 0.0265, 0.9243],
#         [0.0163, 0.0289, 0.9426, 0.0122],
#         [0.9267, 0.0167, 0.0237, 0.0329],
#         [0.0421, 0.0105, 0.0295, 0.9180],
#         [0.0244, 0.0578, 0.9007, 0.0170],
#         [0.0047, 0.9594, 0.0334, 0.0025]], device='cuda:0')
# corrects:: 148
# total: 176
# label:     tensor([0, 0, 3, 2, 2, 2, 3, 2], device='cuda:0')
# predicted: tensor([0, 0, 3, 2, 2, 2, 3, 2], device='cuda:0')
# predicted: tensor([[0.6706, 0.0585, 0.0929, 0.1780],
#         [0.9694, 0.0057, 0.0114, 0.0135],
#         [0.0339, 0.0070, 0.0194, 0.9397],
#         [0.0054, 0.0136, 0.9763, 0.0047],
#         [0.0145, 0.0396, 0.9360, 0.0098],
#         [0.0136, 0.0408, 0.9353, 0.0103],
#         [0.0552, 0.0107, 0.0258, 0.9082],
#         [0.0199, 0.0377, 0.9268, 0.0156]], device='cuda:0')
# corrects:: 156
# total: 184
# label:     tensor([1, 2, 1, 3, 1, 3, 1, 3], device='cuda:0')
# predicted: tensor([1, 2, 1, 3, 1, 3, 1, 3], device='cuda:0')
# predicted: tensor([[5.5090e-02, 8.7201e-01, 5.7906e-02, 1.4991e-02],
#         [5.1428e-03, 1.3602e-02, 9.7740e-01, 3.8576e-03],
#         [1.3135e-03, 9.8410e-01, 1.3939e-02, 6.4755e-04],
#         [1.3703e-01, 4.4744e-02, 1.1110e-01, 7.0713e-01],
#         [6.3601e-03, 9.5487e-01, 3.5189e-02, 3.5836e-03],
#         [4.4144e-01, 4.2982e-02, 7.0562e-02, 4.4501e-01],
#         [2.0166e-02, 8.8920e-01, 8.1943e-02, 8.6947e-03],
#         [1.1018e-01, 3.2826e-02, 7.5575e-02, 7.8142e-01]], device='cuda:0')
# corrects:: 164
# total: 192
# label:     tensor([1, 0, 1, 3, 2, 3, 2, 0], device='cuda:0')
# predicted: tensor([1, 0, 1, 3, 0, 3, 2, 0], device='cuda:0')
# predicted: tensor([[1.7105e-03, 9.7896e-01, 1.8502e-02, 8.2992e-04],
#         [8.7558e-01, 2.6839e-02, 4.1534e-02, 5.6050e-02],
#         [2.7918e-03, 9.7037e-01, 2.5484e-02, 1.3504e-03],
#         [2.6664e-02, 3.9760e-03, 1.0089e-02, 9.5927e-01],
#         [6.5924e-01, 9.8890e-02, 1.2551e-01, 1.1636e-01],
#         [7.8694e-02, 1.6150e-02, 3.4489e-02, 8.7067e-01],
#         [3.8913e-03, 1.1127e-02, 9.8130e-01, 3.6833e-03],
#         [8.9028e-01, 2.7593e-02, 3.5217e-02, 4.6909e-02]], device='cuda:0')
# corrects:: 171
# total: 200
# label:     tensor([3, 3, 2, 0, 3, 2, 0, 0], device='cuda:0')
# predicted: tensor([2, 3, 2, 0, 3, 2, 0, 0], device='cuda:0')
# predicted: tensor([[0.1417, 0.2923, 0.4550, 0.1110],
#         [0.0239, 0.0044, 0.0117, 0.9599],
#         [0.0060, 0.0128, 0.9762, 0.0050],
#         [0.9416, 0.0132, 0.0202, 0.0251],
#         [0.0392, 0.0090, 0.0268, 0.9250],
#         [0.0553, 0.0778, 0.8329, 0.0339],
#         [0.7767, 0.0569, 0.0834, 0.0830],
#         [0.8914, 0.0282, 0.0372, 0.0432]], device='cuda:0')
# corrects:: 178
# total: 208
# label:     tensor([3, 3, 1, 3, 1, 2, 0, 3], device='cuda:0')
# predicted: tensor([3, 3, 1, 1, 1, 2, 0, 0], device='cuda:0')
# predicted: tensor([[3.6399e-02, 6.6653e-03, 1.7308e-02, 9.3963e-01],
#         [9.1858e-02, 5.0348e-02, 3.6781e-02, 8.2101e-01],
#         [8.7026e-03, 9.0915e-01, 7.7959e-02, 4.1872e-03],
#         [1.4657e-01, 4.6342e-01, 1.8785e-01, 2.0216e-01],
#         [6.0187e-04, 9.9022e-01, 8.8925e-03, 2.8123e-04],
#         [1.1585e-02, 3.0879e-02, 9.4850e-01, 9.0342e-03],
#         [9.2239e-01, 1.5800e-02, 3.4145e-02, 2.7668e-02],
#         [7.5532e-01, 2.5315e-02, 3.1008e-02, 1.8836e-01]], device='cuda:0')
# corrects:: 184
# total: 216
# label:     tensor([0, 3, 1, 2, 0, 1, 2, 2], device='cuda:0')
# predicted: tensor([1, 3, 1, 0, 0, 1, 2, 2], device='cuda:0')
# predicted: tensor([[8.4453e-02, 6.3695e-01, 2.4389e-01, 3.4702e-02],
#         [7.3871e-02, 1.6878e-02, 3.7376e-02, 8.7187e-01],
#         [3.5939e-02, 8.4995e-01, 9.4103e-02, 2.0009e-02],
#         [6.5842e-01, 9.9400e-02, 1.2608e-01, 1.1610e-01],
#         [9.7428e-01, 4.7774e-03, 6.2842e-03, 1.4655e-02],
#         [2.6238e-04, 9.9571e-01, 3.8860e-03, 1.4085e-04],
#         [4.3350e-02, 7.9315e-02, 8.4860e-01, 2.8731e-02],
#         [1.0703e-01, 9.8485e-02, 7.2621e-01, 6.8272e-02]], device='cuda:0')
# corrects:: 190
# total: 224
# label:     tensor([1, 2, 1, 3, 0, 1, 2, 2], device='cuda:0')
# predicted: tensor([1, 2, 1, 3, 2, 1, 2, 2], device='cuda:0')
# predicted: tensor([[3.0942e-02, 7.8644e-01, 1.6719e-01, 1.5422e-02],
#         [1.1023e-02, 5.1495e-02, 9.3028e-01, 7.1999e-03],
#         [1.9425e-03, 9.7874e-01, 1.8328e-02, 9.8541e-04],
#         [2.6050e-02, 3.9162e-03, 1.0771e-02, 9.5926e-01],
#         [9.8101e-02, 6.7206e-02, 6.2405e-01, 2.1064e-01],
#         [4.9754e-04, 9.9205e-01, 7.2067e-03, 2.4796e-04],
#         [1.3166e-01, 1.2560e-01, 6.8026e-01, 6.2472e-02],
#         [4.4811e-03, 1.5281e-02, 9.7628e-01, 3.9564e-03]], device='cuda:0')
# corrects:: 197
# total: 232
# label:     tensor([1, 0, 3, 1, 0, 0, 1, 0], device='cuda:0')
# predicted: tensor([1, 0, 3, 1, 0, 0, 1, 0], device='cuda:0')
# predicted: tensor([[1.4920e-02, 6.3595e-01, 3.4328e-01, 5.8545e-03],
#         [5.6651e-01, 1.7372e-01, 1.5510e-01, 1.0467e-01],
#         [2.3443e-02, 4.9909e-03, 1.5827e-02, 9.5574e-01],
#         [4.3398e-04, 9.9382e-01, 5.5182e-03, 2.3032e-04],
#         [7.6937e-01, 6.5078e-02, 8.2762e-02, 8.2786e-02],
#         [9.6565e-01, 6.4148e-03, 1.1162e-02, 1.6771e-02],
#         [8.5088e-02, 7.6079e-01, 1.2874e-01, 2.5384e-02],
#         [9.3815e-01, 1.1858e-02, 2.0221e-02, 2.9771e-02]], device='cuda:0')
# corrects:: 205
# total: 240
# label:     tensor([3, 2, 0, 2, 2, 0, 1, 3], device='cuda:0')
# predicted: tensor([3, 0, 0, 2, 2, 0, 1, 3], device='cuda:0')
# predicted: tensor([[0.1611, 0.0339, 0.0555, 0.7495],
#         [0.7950, 0.0402, 0.0553, 0.1095],
#         [0.9477, 0.0124, 0.0163, 0.0236],
#         [0.0100, 0.0174, 0.9643, 0.0083],
#         [0.0071, 0.0228, 0.9648, 0.0053],
#         [0.6738, 0.0720, 0.1565, 0.0977],
#         [0.0221, 0.5151, 0.4524, 0.0104],
#         [0.0197, 0.0036, 0.0131, 0.9635]], device='cuda:0')
# corrects:: 212
# total: 248
# label:     tensor([1, 0, 3, 2, 2, 1, 3, 0], device='cuda:0')
# predicted: tensor([1, 0, 3, 2, 2, 1, 3, 0], device='cuda:0')
# predicted: tensor([[5.0834e-03, 9.5380e-01, 3.8613e-02, 2.5016e-03],
#         [6.7012e-01, 5.8508e-02, 9.2911e-02, 1.7846e-01],
#         [1.3497e-02, 2.2319e-03, 7.2220e-03, 9.7705e-01],
#         [2.4246e-02, 3.0789e-02, 9.3121e-01, 1.3752e-02],
#         [6.4606e-03, 1.2369e-02, 9.7565e-01, 5.5187e-03],
#         [3.0640e-04, 9.9448e-01, 5.0763e-03, 1.3882e-04],
#         [8.4705e-02, 1.7352e-02, 3.4887e-02, 8.6306e-01],
#         [9.6372e-01, 7.0311e-03, 1.1494e-02, 1.7751e-02]], device='cuda:0')
# corrects:: 220
# total: 256
# label:     tensor([1, 0, 1, 0, 3, 2, 1, 2], device='cuda:0')
# predicted: tensor([1, 0, 1, 0, 3, 2, 1, 2], device='cuda:0')
# predicted: tensor([[3.8192e-03, 9.7110e-01, 2.2976e-02, 2.1001e-03],
#         [8.7691e-01, 2.7388e-02, 4.8727e-02, 4.6972e-02],
#         [2.1429e-02, 7.7083e-01, 1.9793e-01, 9.8147e-03],
#         [8.7575e-01, 2.9967e-02, 4.6243e-02, 4.8039e-02],
#         [5.7756e-02, 1.0365e-02, 2.3437e-02, 9.0844e-01],
#         [9.9545e-03, 2.0185e-02, 9.6216e-01, 7.7032e-03],
#         [1.2044e-04, 9.9628e-01, 3.5487e-03, 4.9372e-05],
#         [3.5770e-02, 5.1687e-02, 8.9221e-01, 2.0335e-02]], device='cuda:0')
# corrects:: 228
# total: 264
# label:     tensor([1, 1, 1, 3, 2, 3, 3, 0], device='cuda:0')
# predicted: tensor([1, 1, 1, 3, 0, 3, 0, 1], device='cuda:0')
# predicted: tensor([[2.2653e-04, 9.9598e-01, 3.6775e-03, 1.1952e-04],
#         [2.4062e-04, 9.9541e-01, 4.2308e-03, 1.2111e-04],
#         [9.1048e-04, 9.8828e-01, 1.0347e-02, 4.6028e-04],
#         [7.3851e-02, 1.6870e-02, 3.7355e-02, 8.7192e-01],
#         [4.6475e-01, 1.9983e-01, 1.6041e-01, 1.7501e-01],
#         [1.5118e-02, 2.6488e-03, 7.4662e-03, 9.7477e-01],
#         [7.5559e-01, 2.5284e-02, 3.0968e-02, 1.8815e-01],
#         [2.5220e-01, 4.1844e-01, 2.7302e-01, 5.6331e-02]], device='cuda:0')
# corrects:: 233
# total: 272
# label:     tensor([0, 0, 2, 0, 3, 2, 3, 2], device='cuda:0')
# predicted: tensor([1, 0, 2, 0, 2, 2, 3, 2], device='cuda:0')
# predicted: tensor([[0.0303, 0.7699, 0.1842, 0.0156],
#         [0.8994, 0.0215, 0.0362, 0.0429],
#         [0.1074, 0.2788, 0.5575, 0.0562],
#         [0.4464, 0.2643, 0.1874, 0.1019],
#         [0.2116, 0.1226, 0.5764, 0.0893],
#         [0.0060, 0.0175, 0.9716, 0.0049],
#         [0.0283, 0.0049, 0.0110, 0.9557],
#         [0.0020, 0.0083, 0.9878, 0.0019]], device='cuda:0')
# corrects:: 239
# total: 280
# label:     tensor([1, 2, 2, 2, 2, 2, 0, 1], device='cuda:0')
# predicted: tensor([3, 2, 1, 2, 1, 2, 2, 1], device='cuda:0')
# predicted: tensor([[6.2345e-02, 1.7049e-02, 4.7557e-02, 8.7305e-01],
#         [8.8313e-02, 1.6332e-01, 6.9299e-01, 5.5377e-02],
#         [9.3733e-02, 4.8000e-01, 3.8245e-01, 4.3825e-02],
#         [9.8762e-02, 1.3126e-01, 7.0646e-01, 6.3517e-02],
#         [9.0285e-04, 9.8912e-01, 9.4957e-03, 4.8541e-04],
#         [1.0498e-02, 2.1608e-02, 9.5874e-01, 9.1503e-03],
#         [3.1700e-01, 1.8403e-01, 4.0184e-01, 9.7134e-02],
#         [4.2610e-05, 9.9857e-01, 1.3647e-03, 1.8582e-05]], device='cuda:0')
# corrects:: 243
# total: 288
# label:     tensor([1, 3, 0, 1, 2, 1, 0, 1], device='cuda:0')
# predicted: tensor([1, 3, 0, 1, 2, 1, 0, 1], device='cuda:0')
# predicted: tensor([[2.8021e-02, 6.8325e-01, 2.7671e-01, 1.2016e-02],
#         [5.1108e-03, 7.4092e-04, 2.6062e-03, 9.9154e-01],
#         [6.8996e-01, 9.3945e-02, 1.0646e-01, 1.0963e-01],
#         [1.8686e-04, 9.9677e-01, 2.9413e-03, 9.7147e-05],
#         [1.3311e-01, 1.2604e-01, 6.7804e-01, 6.2807e-02],
#         [5.0606e-04, 9.9351e-01, 5.7132e-03, 2.7321e-04],
#         [9.4110e-01, 1.1555e-02, 2.0234e-02, 2.7114e-02],
#         [4.0014e-03, 9.6270e-01, 3.1249e-02, 2.0447e-03]], device='cuda:0')
# corrects:: 251
# total: 296
# label:     tensor([2, 2, 3, 3, 0, 0, 0, 0], device='cuda:0')
# predicted: tensor([2, 2, 3, 3, 0, 0, 0, 0], device='cuda:0')
# predicted: tensor([[0.1080, 0.2600, 0.5693, 0.0627],
#         [0.0202, 0.0258, 0.9291, 0.0249],
#         [0.1629, 0.0341, 0.0557, 0.7472],
#         [0.0139, 0.0026, 0.0093, 0.9742],
#         [0.9598, 0.0082, 0.0127, 0.0193],
#         [0.7428, 0.0634, 0.0970, 0.0967],
#         [0.9851, 0.0027, 0.0041, 0.0081],
#         [0.9805, 0.0037, 0.0058, 0.0100]], device='cuda:0')
# corrects:: 259
# total: 304
# label:     tensor([1, 0, 3, 0, 0, 1, 0, 0], device='cuda:0')
# predicted: tensor([1, 0, 3, 3, 0, 1, 0, 0], device='cuda:0')
# predicted: tensor([[2.2191e-03, 9.4845e-01, 4.8473e-02, 8.5624e-04],
#         [8.7250e-01, 2.7742e-02, 3.7885e-02, 6.1876e-02],
#         [1.1579e-01, 3.3892e-02, 6.9718e-02, 7.8060e-01],
#         [1.6549e-01, 4.9665e-02, 8.8445e-02, 6.9640e-01],
#         [9.5726e-01, 8.9934e-03, 1.2642e-02, 2.1100e-02],
#         [3.1103e-02, 7.8543e-01, 1.6798e-01, 1.5487e-02],
#         [9.5845e-01, 8.4674e-03, 1.3046e-02, 2.0041e-02],
#         [6.6911e-01, 6.0969e-02, 1.8243e-01, 8.7496e-02]], device='cuda:0')
# corrects:: 266
# total: 312
# label:     tensor([3, 1, 2, 3, 1, 0, 0, 0], device='cuda:0')
# predicted: tensor([3, 1, 2, 3, 1, 1, 0, 0], device='cuda:0')
# predicted: tensor([[0.0827, 0.0246, 0.0457, 0.8469],
#         [0.0040, 0.9626, 0.0313, 0.0021],
#         [0.0737, 0.0791, 0.8054, 0.0418],
#         [0.0114, 0.0021, 0.0072, 0.9793],
#         [0.0137, 0.9493, 0.0320, 0.0050],
#         [0.1028, 0.4865, 0.3693, 0.0415],
#         [0.8213, 0.0505, 0.0565, 0.0716],
#         [0.9573, 0.0079, 0.0129, 0.0219]], device='cuda:0')
# corrects:: 273
# total: 320
# label:     tensor([1, 3, 2, 0, 3, 2, 2, 3], device='cuda:0')
# predicted: tensor([1, 3, 2, 0, 3, 2, 1, 3], device='cuda:0')
# predicted: tensor([[1.1633e-03, 9.8398e-01, 1.4313e-02, 5.4203e-04],
#         [7.7224e-02, 1.0910e-02, 1.9112e-02, 8.9275e-01],
#         [4.8370e-02, 6.1907e-02, 8.5240e-01, 3.7323e-02],
#         [8.2728e-01, 5.3444e-02, 5.3566e-02, 6.5709e-02],
#         [2.1121e-01, 3.3169e-02, 5.4038e-02, 7.0158e-01],
#         [7.6143e-03, 1.5451e-02, 9.7052e-01, 6.4105e-03],
#         [2.9279e-02, 8.6726e-01, 8.2831e-02, 2.0634e-02],
#         [2.1710e-01, 5.6516e-02, 8.3703e-02, 6.4268e-01]], device='cuda:0')
# corrects:: 280
# total: 328
# acuuracy: 85.36585235595703
